# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


df = pd.read_csv('data.csv')
df.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  num
# 0    ?           0
# 1    ?           0
# 2    ?           0
# 3    6           0
# 4    ?           0

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294 entries, 0 to 293
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         294 non-null    int64
#  1   sex         294 non-null    int64
#  2   cp          294 non-null    int64
#  3   trestbps    294 non-null    object
#  4   chol        294 non-null    object
#  5   fbs         294 non-null    object
#  6   restecg     294 non-null    object
#  7   thalach     294 non-null    object
#  8   exang       294 non-null    object
#  9   oldpeak     294 non-null    float64
#  10  slope       294 non-null    object
#  11  ca          294 non-null    object
#  12  thal        294 non-null    object
#  13  num         294 non-null    int64
# dtypes: float64(1), int64(4), object(9)
# memory usage: 32.3+ KB
#               age         sex          cp     oldpeak  num
# count  294.000000  294.000000  294.000000  294.000000  294.000000
# mean    47.826531    0.724490    2.982993    0.586054    0.360544
# std      7.811812    0.447533    0.965117    0.908648    0.480977
# min     28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     42.000000    0.000000    2.000000    0.000000    0.000000
# 50%     49.000000    1.000000    3.000000    0.000000    0.000000
# 75%     54.000000    1.000000    4.000000    1.000000    1.000000
# max     66.000000    1.000000    4.000000    5.000000    1.000000

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num       '],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
print(df['num'].value_counts())
# Out:
# num
# 0    188
# 1    106
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df.columns = df.columns.str.strip()


df['num'] = pd.to_numeric(df['num'], errors='coerce')
df['chol'] = pd.to_numeric(df['chol'], errors='coerce')

plt.figure(figsize=(8, 5))
sns.boxplot(x='num', y='chol', data=df)
plt.title("Cholesterol Levels by Heart Disease Class (num)")
plt.xlabel("Heart Disease Class (num)")
plt.ylabel("Cholesterol")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
df.replace("?", np.nan, inplace=True)

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Between Features")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


df.columns = df.columns.str.strip()


plt.figure(figsize=(8, 5))
sns.scatterplot(x='age', y='thalach', hue='num', data=df, palette='Set1')
plt.title("Age vs Max Heart Rate by Heart Disease Class")
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate (thalach)")
plt.legend(title='Heart Disease (num)')
plt.grid(True)
plt.show()

# %%
import numpy as np


df.columns = df.columns.str.strip()

# %%
import numpy as np
df = df.replace(r'^\s*\?$', np.nan, regex=True)

# %%
df = df.apply(pd.to_numeric, errors='coerce')

# %%
print(df.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

print("Number of missing values after processing:\n", df.isnull().sum())
# Out:
# Number of missing values after processing:
#  age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
X = df.drop('num', axis=1)
y = df['num']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)


y_pred_dt = dt_model.predict(X_test)

print("Results Decision Tree")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print("\nClassification Report:\n", classification_report(y_test, y_pred_dt))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_dt))
# Out:
# Results Decision Tree
# Accuracy: 0.7457627118644068
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78        38
#            1       0.61      0.81      0.69        21
#
#     accuracy                           0.75        59
#    macro avg       0.74      0.76      0.74        59
# weighted avg       0.78      0.75      0.75        59
#
#
# Confusion Matrix:
#  [[27 11]
#  [ 4 17]]

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plot_tree(dt_model, 
          filled=True, 
          feature_names=df.drop("num", axis=1).columns, 
          class_names=[str(c) for c in sorted(y.unique())], 
          rounded=True)
plt.title("Decision Tree Visualization")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

if len(y.unique()) == 2:
   
    y_proba_dt = dt_model.predict_proba(X_test)[:, 1]

    
    fpr, tpr, thresholds = roc_curve(y_test, y_proba_dt)
    roc_auc = roc_auc_score(y_test, y_proba_dt)

    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'Decision Tree (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')  
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Decision Tree')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()
else:
    print("❗ ROC curve only works for binary classification (2 classes).")

# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

error_rates = []
k_values = range(1, 21)  # Testing K values from 1 to 20

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    pred_k = knn.predict(X_test)
    error = 1 - accuracy_score(y_test, pred_k)
    error_rates.append(error)

# Plotting the Elbow curve
plt.figure(figsize=(10, 6))
plt.plot(k_values, error_rates, marker='o', linestyle='--')
plt.title("📉 Elbow Method - Choosing the Optimal K in KNN")
plt.xlabel("Number of Neighbors (K)")
plt.ylabel("Error Rate")
plt.xticks(k_values)
plt.grid(True)
plt.show()
# Out:
# C:\Users\moham\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128201 (\N{CHART WITH DOWNWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix



knn_model = KNeighborsClassifier(n_neighbors=4)
knn_model.fit(X_train, y_train)


y_pred_knn = knn_model.predict(X_test)


print("Results K-Nearest Neighbors")
print("Accuracy:", accuracy_score(y_test, y_pred_knn))
print("\nClassification Report:\n", classification_report(y_test, y_pred_knn))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_knn))
# Out:
# Results K-Nearest Neighbors
# Accuracy: 0.864406779661017
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        38
#            1       0.84      0.76      0.80        21
#
#     accuracy                           0.86        59
#    macro avg       0.86      0.84      0.85        59
# weighted avg       0.86      0.86      0.86        59
#
#
# Confusion Matrix:
#  [[35  3]
#  [ 5 16]]

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


if len(y.unique()) == 2:
    y_proba_knn = knn_model.predict_proba(X_test)[:, 1]

    fpr_knn, tpr_knn, _ = roc_curve(y_test, y_proba_knn)
    auc_knn = roc_auc_score(y_test, y_proba_knn)

    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr_knn, tpr_knn, label=f'KNN (AUC = {auc_knn:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - KNN')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()
else:
    print("❗ ROC curve only works for binary classification.")

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# KNN
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=4)
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)


from sklearn.metrics import accuracy_score, f1_score

accuracy_dt = accuracy_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt, average='weighted')

accuracy_knn = accuracy_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn, average='weighted')

print("🌳 Decision Tree:")
print("Accuracy:", accuracy_dt)
print("F1 Score:", f1_dt)

print("\n📌 KNN (K=4):")
print("Accuracy:", accuracy_knn)
print("F1 Score:", f1_knn)
# Out:
# 🌳 Decision Tree:
# Accuracy: 0.7457627118644068
# F1 Score: 0.7510264238340878
#
# 📌 KNN (K=4):
# Accuracy: 0.864406779661017
# F1 Score: 0.8627553237722728
